# %% [markdown]
# # Bibliotheken importeren

# %%
import pandas as pd
import random 
import pyodbc
import sqlite3
import matplotlib.pyplot as plt

# !!! SKLEARN IS DEPRECATED, PIP INSTALL "scikit-learn" INSTEAD !!!
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Data inlezen en kolommen selecteren

# %%
# !!! HOEFT DIT ALLEEN TE RUNNEN WANNEER DE DATA NOG NIET IN DE SQLITE DATABASE STAAT !!!

DB = {'servername': r'LAPTOP-NBUM6TMN',
    'database': 'johari'}

ssms_conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + DB['servername'] + 
                     ';DATABASE=' + DB['database'] + ';Trusted_Connection=yes')
ssms_cursor = ssms_conn.cursor()

# Data inlezen van de tabel RETURNED_ITEM
query = "SELECT * FROM RETURNED_ITEM"
df = pd.read_sql(query, ssms_conn)

df.head()

# Naar SQLite database
sqlite_conn = sqlite3.connect('../data/johari.db')
df.to_sql('RETURNED_ITEM', con=sqlite_conn, if_exists='replace', index=False)
# Out:
# C:\Users\Jimmy\AppData\Local\Temp\ipykernel_30980\1705448479.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, ssms_conn)
# 706

# %%
df = df.loc[:, ['RETURNED_PRODUCT_TYPE_id', 'RETURNED_REASON_description', 'RETURNED_quantity']] # Alleen de benodigde kolommen
df.head()
# Out:
#    RETURNED_PRODUCT_TYPE_id RETURNED_REASON_description  RETURNED_quantity
# 0                         1      Unsatisfactory product                  8
# 1                         1          Incomplete product                  2
# 2                         1       Wrong product shipped                 22
# 3                         1       Wrong product ordered                 20
# 4                         3           Defective product                  2

# %% [markdown]
# # One-hot encoding van onafhankelijke niet-numerieke variabelen

# %%
dummies_dataframe = pd.get_dummies(df.loc[:, ['RETURNED_REASON_description']]) # One-hot encoding
dummies_dataframe.columns = dummies_dataframe.columns.str.replace('RETURNED_REASON_description_', '') # Kolomnamen aanpassen
dummies_dataframe.head()
# Out:
#    Defective product  Incomplete product  Unsatisfactory product  \
# 0              False               False                    True
# 1              False                True                   False
# 2              False               False                   False
# 3              False               False                   False
# 4               True               False                   False
#
#    Wrong product ordered  Wrong product shipped
# 0                  False                  False
# 1                  False                  False
# 2                  False                   True
# 3                   True                  False
# 4                  False                  False

# %%
df = pd.concat([df, dummies_dataframe], axis=1) # Dataframes samenvoegen
df = df.drop(columns=['RETURNED_REASON_description']) # Vervangende kolom verwijderen
df = df.loc[:, ['RETURNED_PRODUCT_TYPE_id', 'Defective product', 'Incomplete product', 'Unsatisfactory product', 'Wrong product ordered', 'Wrong product shipped', 'RETURNED_quantity']] # Kolomvolgorde aanpassen
df.head()
# Out:
#    RETURNED_PRODUCT_TYPE_id  Defective product  Incomplete product  \
# 0                         1              False               False
# 1                         1              False                True
# 2                         1              False               False
# 3                         1              False               False
# 4                         3               True               False
#
#    Unsatisfactory product  Wrong product ordered  Wrong product shipped  \
# 0                    True                  False                  False
# 1                   False                  False                  False
# 2                   False                  False                   True
# 3                   False                   True                  False
# 4                   False                  False                  False
#
#    RETURNED_quantity
# 0                  8
# 1                  2
# 2                 22
# 3                 20
# 4                  2

# %% [markdown]
# # Verticaal en horizontaal snijden

# %%
X = df.drop('RETURNED_quantity', axis=1) # Onafhankelijke variabelen
y = df.loc[:, ['RETURNED_quantity']] # Afhankelijke variabele
X
# Out:
#      RETURNED_PRODUCT_TYPE_id  Defective product  Incomplete product  \
# 0                           1              False               False
# 1                           1              False                True
# 2                           1              False               False
# 3                           1              False               False
# 4                           3               True               False
# ..                        ...                ...                 ...
# 701                        10              False               False
# 702                        11              False               False
# 703                        12              False               False
# 704                         6               True               False
# 705                        21              False               False
#
#      Unsatisfactory product  Wrong product ordered  Wrong product shipped
# 0                      True                  False                  False
# 1                     False                  False                  False
# 2                     False                  False                   True
# 3                     False                   True                  False
# 4                     False                  False                  False
# ..                      ...                    ...                    ...
# 701                   False                   True                  False
# 702                    True                  False                  False
# 703                   False                  False                   True
# 704                   False                  False                  False
# 705                   False                   True                  False
#
# [706 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.15,
    random_state=42
)

# %% [markdown]
# # Regressiemodel bouwen

# %%
reg_model = linear_model.LinearRegression()
reg_model = LinearRegression().fit(X_train, y_train)
reg_model
# Out:
# LinearRegression()

# %%
y_pred = reg_model.predict(X_test)
y_pred
# Out:
# array([[ 5.91879249],
#        [ 1.80083873],
#        [ 2.83494189],
#        [32.39591087],
#        [48.68137028],
#        [ 1.80083873],
#        [ 1.28378715],
#        [47.13021554],
#        [28.25949822],
#        [52.30073135],
#        [ 2.83494189],
#        [46.61316396],
#        [ 6.95289565],
#        [ 2.816483  ],
#        [63.81829806],
#        [ 7.48840612],
#        [ 5.42019979],
#        [43.51085447],
#        [ 2.816483  ],
#        [ 4.88468933],
#        [ 6.97135454],
#        [46.09611238],
#        [ 5.93725138],
#        [61.75009174],
#        [ 6.43584407],
#        [ 6.45430296],
#        [ 1.80083873],
#        [ 1.78237984],
#        [64.85240122],
#        [ 7.48840612],
#        [36.01527193],
#        [ 4.88468933],
#        [ 6.97135454],
#        [ 3.86904505],
#        [44.02790605],
#        [50.7495766 ],
#        [ 7.48840612],
#        [49.71547344],
#        [ 0.2312251 ],
#        [37.56642668],
#        [ 4.88468933],
#        [29.29360138],
#        [ 4.88468933],
#        [59.68188541],
#        [ 4.88468933],
#        [63.30124648],
#        [ 5.42019979],
#        [ 6.95289565],
#        [47.13021554],
#        [63.30124648],
#        [ 7.48840612],
#        [ 4.88468933],
#        [ 6.97135454],
#        [49.71547344],
#        [ 0.2312251 ],
#        [ 0.74827668],
#        [ 6.43584407],
#        [ 4.90314821],
#        [ 5.42019979],
#        [-0.2673676 ],
#        [28.25949822],
#        [ 1.26532826],
#        [ 3.35199347],
#        [ 4.36763775],
#        [38.08347826],
#        [51.78367977],
#        [ 4.88468933],
#        [ 3.35199347],
#        [-0.28582648],
#        [58.64778225],
#        [ 3.33353459],
#        [ 4.88468933],
#        [60.71598857],
#        [ 7.48840612],
#        [37.04937509],
#        [ 6.97135454],
#        [ 5.42019979],
#        [ 6.97135454],
#        [52.30073135],
#        [ 1.26532826],
#        [ 1.26532826],
#        [ 2.816483  ],
#        [ 2.29943142],
#        [38.08347826],
#        [47.64726712],
#        [ 0.2312251 ],
#        [ 1.80083873],
#        [60.71598857],
#        [ 6.95289565],
#        [38.08347826],
#        [50.7495766 ],
#        [47.64726712],
#        [ 7.48840612],
#        [63.30124648],
#        [ 4.88468933],
#        [50.7495766 ],
#        [-0.80287806],
#        [47.13021554],
#        [ 6.43584407],
#        [ 4.88468933],
#        [36.01527193],
#        [ 1.80083873],
#        [ 4.88468933],
#        [ 4.38609663],
#        [ 5.42019979],
#        [50.7495766 ]])

# %%
prediction_df = pd.DataFrame(y_pred)
prediction_df = prediction_df.rename(columns={0: 'Predicted_Return_Quantity'})
prediction_df
# Out:
#      Predicted_Return_Quantity
# 0                     5.918792
# 1                     1.800839
# 2                     2.834942
# 3                    32.395911
# 4                    48.681370
# ..                         ...
# 101                   1.800839
# 102                   4.884689
# 103                   4.386097
# 104                   5.420200
# 105                  50.749577
#
# [106 rows x 1 columns]

# %%
y_test_prediction_merge = pd.concat([y_test.reset_index()['RETURNED_quantity'], prediction_df], axis=1)
y_test_prediction_merge.loc[y_test_prediction_merge['Predicted_Return_Quantity'].notna(), :]
y_test_prediction_merge
# Out:
#      RETURNED_quantity  Predicted_Return_Quantity
# 0                    4                   5.918792
# 1                    2                   1.800839
# 2                    2                   2.834942
# 3                   70                  32.395911
# 4                    8                  48.681370
# ..                 ...                        ...
# 101                  4                   1.800839
# 102                  4                   4.884689
# 103                  2                   4.386097
# 104                  2                   5.420200
# 105                 66                  50.749577
#
# [106 rows x 2 columns]

# %%
plt.scatter(y_test_prediction_merge['RETURNED_quantity'], y_test_prediction_merge['Predicted_Return_Quantity'])
plt.xlabel('Actuele Retourhoeveelheid')
plt.ylabel('Schattingsretourhoeveelheid')
plt.title('Actuele retourhoeveelheid vs. Schattingsretourhoeveelheid')
plt.show()

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 664.0962345601708

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 13.326079252843229
